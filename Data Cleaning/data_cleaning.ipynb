# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("messy_customer_sales_data.csv")

# %%
df
# Out:
#       Customer_ID               Name  Gender         Age         City  \
# 0        CUST4371        Paul Wilson      m         52.0     KOLKATA
# 1        CUST5957       Jason Thomas       M  51.0 years          NaN
# 2        CUST3754  Brittney Martinez       F        62.0   hyderabad
# 3        CUST2934      Brenda Pierce  FEMALE        40.0   hyderabad
# 4        CUST5683    Matthew Carroll      f         41.0     CHENNAI
# ...           ...                ...     ...         ...          ...
# 10195   CUST10767       Robert Lewis  female  35.0 years       delhi
# 10196         NaN        Diane Evans       M        53.0   bangalore
# 10197    CUST6315    Joshua Martinez      m         25.0   hyderabad
# 10198    CUST4812       Sarah Miller  FEMALE        55.0          NaN
# 10199    CUST6588       David Potter  female        34.0   HYDERABAD
#
#       Signup_Date Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# ...

# %%
df.info()  #Display information about the DataFrame, including the number of non-null entries and data types for each column.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10200 entries, 0 to 10199
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         9177 non-null   object
#  1   Name                10200 non-null  object
#  2   Gender              9174 non-null   object
#  3   Age                 9249 non-null   object
#  4   City                9184 non-null   object
#  5   Signup_Date         10200 non-null  object
#  6   Last_Purchase_Date  9188 non-null   object
#  7   Purchase_Amount     9179 non-null   float64
#  8   Feedback_Score      9177 non-null   float64
#  9   Email               10200 non-null  object
#  10  Phone_Number        10200 non-null  int64
#  11  Country             9468 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 956.4+ KB

# %%
df.describe().round() #Generate descriptive statistics that summarize the central tendency, dispersion, and shape of a dataset's distribution, excluding NaN values.
# Out:
#        Purchase_Amount  Feedback_Score  Phone_Number
# count           9179.0          9177.0  1.020000e+04
# mean           29090.0             5.0  4.979974e+09
# std           208697.0             3.0  2.902593e+09
# min             -500.0             1.0  9.208990e+05
# 25%            12295.0             3.0  2.449157e+09
# 50%            24330.0             5.0  4.988639e+09
# 75%            37130.0             8.0  7.510448e+09
# max          9999999.0            10.0  9.994402e+09

# %%
df.isnull().sum()/len(df)*100 #Check for missing values in the DataFrame and return the count of missing values for each column.
# Out:
# Customer_ID           10.029412
# Name                   0.000000
# Gender                10.058824
# Age                    9.323529
# City                   9.960784
# Signup_Date            0.000000
# Last_Purchase_Date     9.921569
# Purchase_Amount       10.009804
# Feedback_Score        10.029412
# Email                  0.000000
# Phone_Number           0.000000
# Country                7.176471
# dtype: float64

# %%
df.shape
# Out:
# (10200, 12)

# %%
df.dropna().shape #Drop rows with missing values and return the shape of the resulting DataFrame.
# Out:
# (4528, 12)

# %%
df[df.duplicated()].shape #Check for duplicate rows in the DataFrame and return the shape of the resulting DataFrame.
# Out:
# (15, 12)

# %%
df[df.duplicated()]
# Out:
#       Customer_ID               Name  Gender   Age         City Signup_Date  \
# 2032     CUST2755     Casey Campbell    male   NaN   Hyderabad   2023-12-01
# 3191          NaN   Travis Schneider      f   51.0          NaN  2025-04-20
# 4312     CUST8305       Stanley Cain  FEMALE  51.0   Bangalore   2023-08-14
# 5611     CUST6288       Jonathon Kim    male  46.0     Chennai   2023-11-22
# 5680     CUST2695        Lisa Durham     NaN  46.0     Chennai   2021-04-18
# 5899     CUST8841        Amanda Hill     NaN  34.0     chennai   2022-09-11
# 6070    CUST10780        Emily Smith     NaN  23.0     Kolkata   2023-12-09
# 6240     CUST9745      David Morales     NaN  56.0          NaN  2023-02-18
# 6425     CUST4631       George Villa      m   26.0      Mumbai   2022-05-21
# 6498     CUST1711  Stephanie Elliott     NaN  44.0      MUMBAI   2023-05-17
# 7118     CUST9380        Paul Wilson    MALE  42.0   Bangalore   2025-07-31
# ...

# %%
df['Customer_ID'].value_counts().head(10) #Count the occurrences of each unique value in the 'Customer_ID' column.
# Out:
# Customer_ID
# CUST3344     2
# CUST4893     2
# CUST7000     2
# CUST10824    2
# CUST2695     2
# CUST4390     2
# CUST4186     2
# CUST2242     2
# CUST8746     2
# CUST1299     2
# Name: count, dtype: int64

# %%
df[df['Customer_ID'] == 'CUST4893']
# Out:
#      Customer_ID           Name Gender   Age      City Signup_Date  \
# 2810    CUST4893  Jeffrey Joyce      F  55.0   mumbai   2021-03-07
# 5829    CUST4893  Jeffrey Joyce      F  55.0   MUMBAI   2021-03-07
#
#      Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# 2810         2024-12-26          20321.0             9.0
# 5829         2024-12-26          20321.0             9.0
#
#                           Email  Phone_Number Country
# 2810  garrettteresa@example.com    2317002741   India
# 5829  garrettteresa@example.com    2317002741   India

# %%
for col in df.columns:
    if df[col].nunique() < 20:
        print(df[col].value_counts())
        print('-'*50)
# Out:
# Gender
# f         1184
# M         1171
# m         1163
# F         1157
# MALE      1131
# female    1128
# male      1121
# FEMALE    1119
# Name: count, dtype: int64
# --------------------------------------------------
# City
# Kolkata       820
# Mumbai        812
# Chennai       784
# Bangalore     773
# Hyderabad     770
# Delhi         763
# CHENNAI       404
# KOLKATA       395
# MUMBAI        393
# hyderabad     384
# bangalore     383
# DELHI         378
# delhi         369
# BANGALORE     363
# HYDERABAD     360
# mumbai        352
# chennai       343
# kolkata       338
# Name: count, dtype: int64
# --------------------------------------------------
# Feedback_Score
# 2.0     952
# 4.0     947
# 7.0     938
# 6.0     927
# 3.0     913
# 8.0     912
# 1.0     907
# 9.0     903
# 10.0    901
# 5.0     877
# Name: count, dtype: int64
# --------------------------------------------------
# Country
# India    7132
# IND       793
# india     772
# InDia     771
# ...

# %%
df.dropna(subset=['Customer_ID'], inplace=True) #Drop rows with missing values in the 'Customer_ID' column.
df
# Out:
#       Customer_ID               Name  Gender         Age         City  \
# 0        CUST4371        Paul Wilson      m         52.0     KOLKATA
# 1        CUST5957       Jason Thomas       M  51.0 years          NaN
# 2        CUST3754  Brittney Martinez       F        62.0   hyderabad
# 3        CUST2934      Brenda Pierce  FEMALE        40.0   hyderabad
# 4        CUST5683    Matthew Carroll      f         41.0     CHENNAI
# ...           ...                ...     ...         ...          ...
# 10194    CUST6146      Cody Thompson      f         40.0          NaN
# 10195   CUST10767       Robert Lewis  female  35.0 years       delhi
# 10197    CUST6315    Joshua Martinez      m         25.0   hyderabad
# 10198    CUST4812       Sarah Miller  FEMALE        55.0          NaN
# 10199    CUST6588       David Potter  female        34.0   HYDERABAD
#
#       Signup_Date Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# ...

# %%
df.isnull().sum() #Check for missing values in the DataFrame and return the count of missing values for each column.
# Out:
# Customer_ID             0
# Name                    0
# Gender                934
# Age                   859
# City                  918
# Signup_Date             0
# Last_Purchase_Date    914
# Purchase_Amount       927
# Feedback_Score        905
# Email                   0
# Phone_Number            0
# Country               664
# dtype: int64

# %%
df['Age'].unique()
# Out:
# array(['52.0', '51.0 years', '62.0', '40.0', '41.0', nan, '18.0',
#        '43.0 years', '40.0 years', '26.0', '32.0', '22.0', '59.0', '65.0',
#        '61.0', '31.0', '54.0 years', '55.0', '69.0', '61.0 years', '24.0',
#        '63.0', '19.0', '50.0', '56.0', '36.0', '68.0', '43.0', '38.0',
#        '27.0', '57.0 years', '23.0', '25.0', '66.0', '28.0', '30.0',
#        '46.0', '48.0', '20.0', '37.0', '67.0', '51.0', '35.0', '58.0',
#        '29.0', 'nan years', '39.0', '49.0', '47.0', '42.0', '44.0',
#        '64.0', '53.0', '60.0', '59.0 years', '45.0', '21.0', '34.0',
#        '54.0', '48.0 years', '46.0 years', '33.0', '57.0', '30.0 years',
#        '58.0 years', '35.0 years', '34.0 years', '69.0 years', '250',
#        '19.0 years', '27.0 years', '53.0 years', '65.0 years',
#        '66.0 years', '44.0 years', '49.0 years', '25.0 years',
#        '23.0 years', '62.0 years', '41.0 years', '33.0 years',
#        '28.0 years', '22.0 years', '20.0 years', '42.0 years',
# ...

# %%
import re

def extract_age(age):
    age_num = re.findall('[0-9]+', str(age))
    if len(age_num) > 0:
        return age_num[0]
    else:
        return age
df['Age'] = df['Age'].apply(extract_age) #Extract age values from the 'Age' column.

# %%
df_age = df[df['Age'] != 'nan years']['Age'] #Filter the DataFrame to exclude rows where the 'Age' column contains the string 'nan years'.

# %%
age_median = int(df_age.dropna().astype('int64').median())   #Calculate the median of the 'Age' column after dropping missing values and converting the data type to integer.

# %%
age_median
# Out:
# 43

# %%
df.replace('nan years', age_median, inplace=True) #Replace occurrences of the string 'nan years' in the DataFrame with the calculated median age.

# %%
df['Age'].fillna(age_median, inplace=True) #Fill missing values in the 'Age' column with the mean of the column.
# Out:
# C:\Users\kusha\AppData\Local\Temp\ipykernel_16788\1798590821.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(age_median, inplace=True) #Fill missing values in the 'Age' column with the mean of the column.

# %%
df['Age'].unique() #Return the unique values in the 'Age' column.
# Out:
# array(['52', '51', '62', '40', '41', 43, '18', '43', '26', '32', '22',
#        '59', '65', '61', '31', '54', '55', '69', '24', '63', '19', '50',
#        '56', '36', '68', '38', '27', '57', '23', '25', '66', '28', '30',
#        '46', '48', '20', '37', '67', '35', '58', '29', '39', '49', '47',
#        '42', '44', '64', '53', '60', '45', '21', '34', '33', '250', '3',
#        '10'], dtype=object)

# %%
df['Purchase_Amount'].fillna(df['Purchase_Amount'].median(), inplace=True) #Fill missing values in the 'Purchase_Amount' column with the median of the column.
# Out:
# C:\Users\kusha\AppData\Local\Temp\ipykernel_16788\1110861344.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Purchase_Amount'].fillna(df['Purchase_Amount'].median(), inplace=True) #Fill missing values in the 'Purchase_Amount' column with the median of the column.

# %%
df['Feedback_Score'].fillna(df['Feedback_Score'].mode()[0], inplace=True) #Fill missing values in the 'Feedback' column with the mode of the column.
# Out:
# C:\Users\kusha\AppData\Local\Temp\ipykernel_16788\593858177.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Feedback_Score'].fillna(df['Feedback_Score'].mode()[0], inplace=True) #Fill missing values in the 'Feedback' column with the mode of the column.

# %%
df.isnull().sum() #Check for missing values in the DataFrame and return the count of missing values for each column.
# Out:
# Customer_ID             0
# Name                    0
# Gender                934
# Age                     0
# City                  918
# Signup_Date             0
# Last_Purchase_Date    914
# Purchase_Amount         0
# Feedback_Score          0
# Email                   0
# Phone_Number            0
# Country               664
# dtype: int64

# %%
for col in ['Gender' , 'City' , 'Country']:
    df[col].fillna(df[col].mode()[0], inplace=True) #Fill missing values in the specified columns with the mode of each column.
# Out:
# C:\Users\kusha\AppData\Local\Temp\ipykernel_16788\1196471001.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True) #Fill missing values in the specified columns with the mode of each column.

# %%
df['Last_Purchase_Date'].ffill(inplace=True) #Fill missing values in the 'Last_Purchase_Date' column using forward fill method.
# Out:
# C:\Users\kusha\AppData\Local\Temp\ipykernel_16788\1854595012.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Last_Purchase_Date'].ffill(inplace=True) #Fill missing values in the 'Last_Purchase_Date' column using forward fill method.

# %%
df
# Out:
#       Customer_ID               Name  Gender Age         City Signup_Date  \
# 0        CUST4371        Paul Wilson      m   52     KOLKATA   2025-06-26
# 1        CUST5957       Jason Thomas       M  51     Kolkata   2021-02-17
# 2        CUST3754  Brittney Martinez       F  62   hyderabad   2023-11-05
# 3        CUST2934      Brenda Pierce  FEMALE  40   hyderabad   2022-03-13
# 4        CUST5683    Matthew Carroll      f   41     CHENNAI   2024-04-05
# ...           ...                ...     ...  ..          ...         ...
# 10194    CUST6146      Cody Thompson      f   40     Kolkata   2024-08-21
# 10195   CUST10767       Robert Lewis  female  35       delhi   2020-12-08
# 10197    CUST6315    Joshua Martinez      m   25   hyderabad   2022-02-15
# 10198    CUST4812       Sarah Miller  FEMALE  55     Kolkata   2021-03-16
# 10199    CUST6588       David Potter  female  34   HYDERABAD   2020-10-12
#
#       Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# ...

# %%
df['Gender'].unique()
# Out:
# array(['m ', 'M', 'F', 'FEMALE', 'f ', 'male', 'MALE', 'female'],
#       dtype=object)

# %%
df['Gender'] = df['Gender'].str.lower().str.strip() #Convert all values in the 'Gender' column

# %%
df['Gender'].replace({'f': 'female', 'm': 'male'}, inplace=True) #Replace occurrences of 'f' with 'female' and 'm' with
# Out:
# C:\Users\kusha\AppData\Local\Temp\ipykernel_16788\4032736072.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].replace({'f': 'female', 'm': 'male'}, inplace=True) #Replace occurrences of 'f' with 'female' and 'm' with

# %%
df['City'] = df['City'].str.strip().str.upper() #Remove leading and trailing whitespace from the 'City' column, convert all values to uppercase, and return the unique values.

# %%
df['Country'] = df['Country'].str.strip().str.upper() #Remove leading and trailing whitespace from the 'Country' column, convert all values to uppercase, and return the unique values.

# %%
df['City'].unique()
# Out:
# array(['KOLKATA', 'HYDERABAD', 'CHENNAI', 'BANGALORE', 'MUMBAI', 'DELHI'],
#       dtype=object)

# %%
df['Country'] = df['Country'].str.strip().str.upper() #Remove leading and trailing whitespace from the 'Country' column, convert all values to uppercase, and return the unique values.

# %%
df['Country'].replace({'IND':'INDIA'}, inplace=True)
# Out:
# C:\Users\kusha\AppData\Local\Temp\ipykernel_16788\1962036933.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Country'].replace({'IND':'INDIA'}, inplace=True)

# %%
df['Country']
# Out:
# 0        INDIA
# 1        INDIA
# 2        INDIA
# 3        INDIA
# 4        INDIA
#          ...
# 10194    INDIA
# 10195    INDIA
# 10197    INDIA
# 10198    INDIA
# 10199    INDIA
# Name: Country, Length: 9177, dtype: object

# %%
df[df.duplicated()].shape
# Out:
# (163, 12)

# %%
df.drop_duplicates(inplace=True) #Drop duplicate rows from the DataFrame.

# %%
df['Customer_ID'].value_counts() #Count the occurrences of each unique value in the 'Customer_ID' column.
# Out:
# Customer_ID
# CUST3693    2
# CUST6833    2
# CUST5341    2
# CUST1002    2
# CUST9950    2
#            ..
# CUST7857    1
# CUST3881    1
# CUST1565    1
# CUST9038    1
# CUST5957    1
# Name: count, Length: 9000, dtype: int64

# %%
df[df['Customer_ID']=='CUST3693']
# Out:
#      Customer_ID            Name  Gender Age     City Signup_Date  \
# 3967    CUST3693  Chad Dominguez  female   3  CHENNAI  2022-01-20
# 4953    CUST3693  Chad Dominguez  female  54  CHENNAI  2022-01-20
#
#      Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# 3967         2025-02-20          24268.0             7.0
# 4953         2025-02-20          24268.0             7.0
#
#                         Email  Phone_Number Country
# 3967  donnaacosta@example.net    7342776270   INDIA
# 4953  donnaacosta@example.net    7342776270   INDIA

# %%
df.drop_duplicates(subset=['Customer_ID'], keep='first', inplace=True) #Drop duplicate rows based on the 'Customer_ID' column, keeping the first occurrence.

# %%
df.shape
# Out:
# (9000, 12)

# %%
df['Age']=df['Age'].astype('int64')

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Name', 'Gender', 'Age', 'City', 'Signup_Date',
#        'Last_Purchase_Date', 'Purchase_Amount', 'Feedback_Score', 'Email',
#        'Phone_Number', 'Country'],
#       dtype='object')

# %%
df['Signup_Date'] = pd.to_datetime(df['Signup_Date'])

# %%
df['Last_Purchase_Date'] = pd.to_datetime(df['Last_Purchase_Date'])

# %%
df.dtypes
# Out:
# Customer_ID                   object
# Name                          object
# Gender                        object
# Age                            int64
# City                          object
# Signup_Date           datetime64[ns]
# Last_Purchase_Date    datetime64[ns]
# Purchase_Amount              float64
# Feedback_Score               float64
# Email                         object
# Phone_Number                   int64
# Country                       object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cols = ['Age', 'Purchase_Amount', 'Feedback_Score']

plt.figure(figsize=(15, 5))

for i, col in enumerate(cols, 1):
    plt.subplot(1, 3, i)
    sns.boxplot(y=df_clean[col], color='skyblue', width=0.3)
    plt.title(f'Boxplot of {col}', fontsize=12)
    plt.ylabel('')
    plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %%
cols = ['Age', 'Purchase_Amount', 'Feedback_Score']

print(df[cols].dtypes)
# Out:
# Age                  int64
# Purchase_Amount    float64
# Feedback_Score     float64
# dtype: object

# %%
from scipy import stats

# %%
import numpy as np
z_scores = np.abs(stats.zscore(df[['Age','Purchase_Amount']]))

# %%
df_clean = df[~(z_scores>3).any(axis=1)]

# %%
df_clean.shape
# Out:
# (8989, 12)
